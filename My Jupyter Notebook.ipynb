# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Name: Rida Abdulwahab**
# Desired Occupation: Data Scientist

# %% [markdown]
# *I am interested in being a data scientist because it is fun and I want to work with data

# %% [markdown]
# ### The code below is supposed to show the addition between two number

# %%
1+1
# Out:
# 2

# %% [markdown]
# - bail
# - banner
# - bullet
#
# [blue_text](https://www.google.com/)
#
# ![Aruba_GettyImages-170618386.webp](attachment:fd0d9806-dc7c-4c73-8fc9-a2ba9655aae8.webp)
